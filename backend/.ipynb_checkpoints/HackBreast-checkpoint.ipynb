# %%
import pandas as pd
import numpy as np
from sklearn.neighbors import LocalOutlierFactor
import math

filename = "breast-cancer-wisconsin.data.txt"

# Initialize datafrmae
dataframe = pd.read_csv(filename, header=None)
dataframe = dataframe.drop(0, 1)
columns = ['ClTh', 'UnCeSi', 'UnCeSh', 'MaAd', 'SiEpCeSi', 'BaNu', 
           'BlCh', 'NoNu', 'Mitoses', 'Class']
dataframe.columns = columns

# Clean out missing values
dataframe = dataframe[dataframe.BaNu != '?']
dataframe = dataframe.reset_index(drop=True)
dataframe = dataframe.astype(int)

# Clean out outliers
LOF = LocalOutlierFactor(n_neighbors = 200)
Local = LOF.fit_predict(dataframe.drop(['Class'], axis=1))
dataframe['LOF_det'] = Local

# Drop outlier column 
dataframe = dataframe[dataframe.LOF_det != -1]
dataframe = dataframe.drop(['LOF_det'], axis=1)
dataframe = dataframe.reset_index(drop=True)

# Change class values from 4,2 to 1,0
dataframe['Class'] = dataframe['Class'].replace(4, 1)
dataframe['Class'] = dataframe['Class'].replace(2, 0)

# Split data 80-20
len_data = len(dataframe.index)
len_split = math.ceil(len_data * 0.8)
dataTest = dataframe.head(len_data - len_split)
dataTrain = dataframe.head(len_split)

# Get X and Y Data
X_train = dataTrain.drop('Class', 1)
Y_train = dataTrain.Class
X_test = dataTest.drop('Class', 1)
Y_test = dataTest.Class

# print(X_test)
# print(Y_test)

# print(dataframe)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/neighbors/lof.py:236: FutureWarning: default contamination parameter 0.1 will change in version 0.22 to "auto". This will change the predict method behavior.
#   FutureWarning)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

LogReg = LogisticRegression()
LogReg.fit(X_train, Y_train)
# scores = cross_val_score(LogReg, X_train.values, Y_train.values, 5)
# print("Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2))

LogReg.score(X_test.values, Y_test.values)

# x_sample = X_data.iloc[3].values
# x_sample = x_sample.reshape(1, -1)
# print(x_sample)
# print(LogReg.predict(x_sample))
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# 0.9836065573770492

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras import metrics
from sklearn.preprocessing import LabelEncoder
from keras.models import model_from_json
import os


model = Sequential()
model.add(Dense(3, input_dim=9, activation='relu'))
model.add(Dense(3, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

model.compile(optimizer='sgd', loss='binary_crossentropy', metrics=['accuracy'])

model.summary()


fitModel = model.fit(X_train.values, Y_train.values, batch_size=10, epochs=100, 
                      validation_data=(X_test.values, Y_test.values))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 3)                 30
# _________________________________________________________________
# dense_5 (Dense)              (None, 3)                 12
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 4
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
# Train on 492 samples, validate on 122 samples
# Epoch 1/100
# 492/492 [==============================] - 0s 789us/step - loss: 0.7593 - acc: 0.4228 - val_loss: 0.7223 - val_acc: 0.4426
# Epoch 2/100
# 492/492 [==============================] - 0s 173us/step - loss: 0.6289 - acc: 0.6138 - val_loss: 0.6322 - val_acc: 0.6393
# Epoch 3/100
# 492/492 [==============================] - 0s 418us/step - loss: 0.5724 - acc: 0.7073 - val_loss: 0.5752 - val_acc: 0.6803
# Epoch 4/100
# 492/492 [==============================] - 0s 312us/step - loss: 0.5253 - acc: 0.8476 - val_loss: 0.5296 - val_acc: 0.8443
# Epoch 5/100
# 492/492 [==============================] - 0s 302us/step - loss: 0.4804 - acc: 0.9207 - val_loss: 0.4922 - val_acc: 0.9262
# Epoch 6/100
# 492/492 [==============================] - 0s 300us/step - loss: 0.4396 - acc: 0.9472 - val_loss: 0.4494 - val_acc: 0.9098
# Epoch 7/100
# 492/492 [==============================] - 0s 256us/step - loss: 0.4045 - acc: 0.9533 - val_loss: 0.4153 - val_acc: 0.9508
# Epoch 8/100
# 492/492 [==============================] - 0s 175us/step - loss: 0.3727 - acc: 0.9654 - val_loss: 0.3890 - val_acc: 0.9508
# Epoch 9/100
# 492/492 [==============================] - 0s 300us/step - loss: 0.3465 - acc: 0.9634 - val_loss: 0.3580 - val_acc: 0.9590
# Epoch 10/100
# 492/492 [==============================] - 0s 240us/step - loss: 0.3194 - acc: 0.9695 - val_loss: 0.3384 - val_acc: 0.9508
# Epoch 11/100
# 492/492 [==============================] - 0s 170us/step - loss: 0.3014 - acc: 0.9654 - val_loss: 0.3176 - val_acc: 0.9590
# Epoch 12/100
# 492/492 [==============================] - 0s 208us/step - loss: 0.2814 - acc: 0.9715 - val_loss: 0.2917 - val_acc: 0.9508
# Epoch 13/100
# 492/492 [==============================] - 0s 186us/step - loss: 0.2627 - acc: 0.9736 - val_loss: 0.2993 - val_acc: 0.9590
# Epoch 14/100
# 492/492 [==============================] - 0s 270us/step - loss: 0.2506 - acc: 0.9715 - val_loss: 0.2578 - val_acc: 0.9672
# Epoch 15/100
# 492/492 [==============================] - 0s 195us/step - loss: 0.2378 - acc: 0.9715 - val_loss: 0.3295 - val_acc: 0.9262
# Epoch 16/100
# 492/492 [==============================] - 0s 202us/step - loss: 0.2274 - acc: 0.9776 - val_loss: 0.2305 - val_acc: 0.9672
# Epoch 17/100
# 492/492 [==============================] - 0s 192us/step - loss: 0.2144 - acc: 0.9776 - val_loss: 0.2187 - val_acc: 0.9754
# Epoch 18/100
# 492/492 [==============================] - 0s 198us/step - loss: 0.2057 - acc: 0.9756 - val_loss: 0.2079 - val_acc: 0.9672
# Epoch 19/100
# 492/492 [==============================] - 0s 277us/step - loss: 0.1968 - acc: 0.9817 - val_loss: 0.2045 - val_acc: 0.9672
# Epoch 20/100
# 492/492 [==============================] - 0s 332us/step - loss: 0.1904 - acc: 0.9797 - val_loss: 0.1897 - val_acc: 0.9836
# Epoch 21/100
# 492/492 [==============================] - 0s 180us/step - loss: 0.1826 - acc: 0.9797 - val_loss: 0.1872 - val_acc: 0.9672
# Epoch 22/100
# 492/492 [==============================] - 0s 232us/step - loss: 0.1761 - acc: 0.9797 - val_loss: 0.1751 - val_acc: 0.9836
# Epoch 23/100
# 492/492 [==============================] - 0s 217us/step - loss: 0.1704 - acc: 0.9837 - val_loss: 0.1705 - val_acc: 0.9754
# Epoch 24/100
# 492/492 [==============================] - 0s 179us/step - loss: 0.1656 - acc: 0.9837 - val_loss: 0.1637 - val_acc: 0.9836
# Epoch 25/100
# 492/492 [==============================] - 0s 221us/step - loss: 0.1597 - acc: 0.9797 - val_loss: 0.1579 - val_acc: 0.9836
# Epoch 26/100
# 492/492 [==============================] - 0s 227us/step - loss: 0.1548 - acc: 0.9797 - val_loss: 0.1538 - val_acc: 0.9836
# Epoch 27/100
# 492/492 [==============================] - 0s 203us/step - loss: 0.1519 - acc: 0.9817 - val_loss: 0.1495 - val_acc: 0.9836
# Epoch 28/100
# 492/492 [==============================] - 0s 197us/step - loss: 0.1487 - acc: 0.9817 - val_loss: 0.1448 - val_acc: 0.9836
# Epoch 29/100
# 492/492 [==============================] - 0s 354us/step - loss: 0.1444 - acc: 0.9837 - val_loss: 0.1451 - val_acc: 0.9754
# Epoch 30/100
# 492/492 [==============================] - 0s 208us/step - loss: 0.1406 - acc: 0.9817 - val_loss: 0.1405 - val_acc: 0.9836
# Epoch 31/100
# 492/492 [==============================] - 0s 212us/step - loss: 0.1376 - acc: 0.9837 - val_loss: 0.1370 - val_acc: 0.9836
# Epoch 32/100
# 492/492 [==============================] - 0s 186us/step - loss: 0.1335 - acc: 0.9817 - val_loss: 0.1296 - val_acc: 0.9836
# Epoch 33/100
# 492/492 [==============================] - 0s 223us/step - loss: 0.1318 - acc: 0.9837 - val_loss: 0.1285 - val_acc: 0.9836
# Epoch 34/100
# 492/492 [==============================] - 0s 140us/step - loss: 0.1286 - acc: 0.9837 - val_loss: 0.1261 - val_acc: 0.9836
# Epoch 35/100
# 492/492 [==============================] - 0s 131us/step - loss: 0.1270 - acc: 0.9837 - val_loss: 0.1217 - val_acc: 0.9836
# Epoch 36/100
# 492/492 [==============================] - 0s 135us/step - loss: 0.1241 - acc: 0.9837 - val_loss: 0.1194 - val_acc: 0.9836
# Epoch 37/100
# 492/492 [==============================] - 0s 135us/step - loss: 0.1206 - acc: 0.9837 - val_loss: 0.1209 - val_acc: 0.9836
# Epoch 38/100
# 492/492 [==============================] - 0s 148us/step - loss: 0.1191 - acc: 0.9837 - val_loss: 0.1134 - val_acc: 0.9836
# Epoch 39/100
# 492/492 [==============================] - 0s 240us/step - loss: 0.1176 - acc: 0.9837 - val_loss: 0.1224 - val_acc: 0.9754
# Epoch 40/100
# 492/492 [==============================] - 0s 171us/step - loss: 0.1160 - acc: 0.9837 - val_loss: 0.1149 - val_acc: 0.9836
# Epoch 41/100
# 492/492 [==============================] - 0s 172us/step - loss: 0.1144 - acc: 0.9837 - val_loss: 0.1075 - val_acc: 0.9836
# Epoch 42/100
# 492/492 [==============================] - 0s 322us/step - loss: 0.1121 - acc: 0.9837 - val_loss: 0.1091 - val_acc: 0.9836
# Epoch 43/100
# 492/492 [==============================] - 0s 233us/step - loss: 0.1106 - acc: 0.9837 - val_loss: 0.1036 - val_acc: 0.9836
# Epoch 44/100
# 492/492 [==============================] - 0s 177us/step - loss: 0.1083 - acc: 0.9837 - val_loss: 0.1437 - val_acc: 0.9836
# Epoch 45/100
# 492/492 [==============================] - 0s 143us/step - loss: 0.1085 - acc: 0.9837 - val_loss: 0.1002 - val_acc: 0.9836
# Epoch 46/100
# 492/492 [==============================] - 0s 150us/step - loss: 0.1063 - acc: 0.9837 - val_loss: 0.0998 - val_acc: 0.9836
# Epoch 47/100
# 492/492 [==============================] - 0s 165us/step - loss: 0.1044 - acc: 0.9837 - val_loss: 0.0972 - val_acc: 0.9836
# Epoch 48/100
# 492/492 [==============================] - 0s 273us/step - loss: 0.1016 - acc: 0.9837 - val_loss: 0.0953 - val_acc: 0.9836
# Epoch 49/100
# 492/492 [==============================] - 0s 202us/step - loss: 0.1023 - acc: 0.9837 - val_loss: 0.0984 - val_acc: 0.9836
# Epoch 50/100
# 492/492 [==============================] - 0s 220us/step - loss: 0.1012 - acc: 0.9837 - val_loss: 0.0935 - val_acc: 0.9836
# Epoch 51/100
# 492/492 [==============================] - 0s 218us/step - loss: 0.0992 - acc: 0.9837 - val_loss: 0.0940 - val_acc: 0.9836
# Epoch 52/100
# 492/492 [==============================] - 0s 229us/step - loss: 0.0984 - acc: 0.9837 - val_loss: 0.0909 - val_acc: 0.9836
# Epoch 53/100
# 492/492 [==============================] - 0s 129us/step - loss: 0.0973 - acc: 0.9837 - val_loss: 0.0896 - val_acc: 0.9836
# Epoch 54/100
# 492/492 [==============================] - 0s 138us/step - loss: 0.0957 - acc: 0.9837 - val_loss: 0.0880 - val_acc: 0.9836
# Epoch 55/100
# 492/492 [==============================] - 0s 135us/step - loss: 0.0955 - acc: 0.9837 - val_loss: 0.0866 - val_acc: 0.9836
# Epoch 56/100
# 492/492 [==============================] - 0s 143us/step - loss: 0.0942 - acc: 0.9837 - val_loss: 0.0855 - val_acc: 0.9836
# Epoch 57/100
# 492/492 [==============================] - 0s 130us/step - loss: 0.0937 - acc: 0.9837 - val_loss: 0.0846 - val_acc: 0.9836
# Epoch 58/100
# 492/492 [==============================] - 0s 135us/step - loss: 0.0917 - acc: 0.9837 - val_loss: 0.0840 - val_acc: 0.9836
# Epoch 59/100
# 492/492 [==============================] - 0s 132us/step - loss: 0.0930 - acc: 0.9837 - val_loss: 0.0826 - val_acc: 0.9836
# Epoch 60/100
# 492/492 [==============================] - 0s 174us/step - loss: 0.0904 - acc: 0.9837 - val_loss: 0.0816 - val_acc: 0.9836
# Epoch 61/100
# 492/492 [==============================] - 0s 482us/step - loss: 0.0881 - acc: 0.9837 - val_loss: 0.0819 - val_acc: 0.9836
# Epoch 62/100
# 492/492 [==============================] - 0s 143us/step - loss: 0.0891 - acc: 0.9837 - val_loss: 0.0800 - val_acc: 0.9836
# Epoch 63/100
# 492/492 [==============================] - 0s 163us/step - loss: 0.0884 - acc: 0.9837 - val_loss: 0.0814 - val_acc: 0.9836
# Epoch 64/100
# 492/492 [==============================] - 0s 216us/step - loss: 0.0880 - acc: 0.9837 - val_loss: 0.0796 - val_acc: 0.9836
# Epoch 65/100
# 492/492 [==============================] - 0s 210us/step - loss: 0.0862 - acc: 0.9837 - val_loss: 0.0871 - val_acc: 0.9836
# Epoch 66/100
# 492/492 [==============================] - 0s 205us/step - loss: 0.0856 - acc: 0.9837 - val_loss: 0.0767 - val_acc: 0.9836
# Epoch 67/100
# 492/492 [==============================] - 0s 179us/step - loss: 0.0850 - acc: 0.9837 - val_loss: 0.0831 - val_acc: 0.9836
# Epoch 68/100
# 492/492 [==============================] - 0s 131us/step - loss: 0.0843 - acc: 0.9837 - val_loss: 0.0769 - val_acc: 0.9836
# Epoch 69/100
# 492/492 [==============================] - 0s 144us/step - loss: 0.0837 - acc: 0.9837 - val_loss: 0.0748 - val_acc: 0.9836
# Epoch 70/100
# 492/492 [==============================] - 0s 137us/step - loss: 0.0834 - acc: 0.9837 - val_loss: 0.0738 - val_acc: 0.9836
# Epoch 71/100
# 492/492 [==============================] - 0s 252us/step - loss: 0.0828 - acc: 0.9837 - val_loss: 0.0755 - val_acc: 0.9836
# Epoch 72/100
# 492/492 [==============================] - 0s 165us/step - loss: 0.0820 - acc: 0.9837 - val_loss: 0.0727 - val_acc: 0.9836
# Epoch 73/100
# 492/492 [==============================] - 0s 128us/step - loss: 0.0822 - acc: 0.9837 - val_loss: 0.0718 - val_acc: 0.9836
# Epoch 74/100
# 492/492 [==============================] - 0s 133us/step - loss: 0.0814 - acc: 0.9837 - val_loss: 0.0723 - val_acc: 0.9836
# Epoch 75/100
# 492/492 [==============================] - 0s 146us/step - loss: 0.0796 - acc: 0.9837 - val_loss: 0.0709 - val_acc: 0.9836
# Epoch 76/100
# 492/492 [==============================] - 0s 153us/step - loss: 0.0813 - acc: 0.9837 - val_loss: 0.0700 - val_acc: 0.9836
# Epoch 77/100
# 492/492 [==============================] - 0s 145us/step - loss: 0.0798 - acc: 0.9837 - val_loss: 0.0698 - val_acc: 0.9836
# Epoch 78/100
# 492/492 [==============================] - 0s 136us/step - loss: 0.0777 - acc: 0.9837 - val_loss: 0.0717 - val_acc: 0.9836
# Epoch 79/100
# 492/492 [==============================] - 0s 150us/step - loss: 0.0791 - acc: 0.9837 - val_loss: 0.0695 - val_acc: 0.9836
# Epoch 80/100
# 492/492 [==============================] - 0s 178us/step - loss: 0.0786 - acc: 0.9837 - val_loss: 0.0701 - val_acc: 0.9836
# Epoch 81/100
# 492/492 [==============================] - 0s 183us/step - loss: 0.0773 - acc: 0.9837 - val_loss: 0.0674 - val_acc: 0.9836
# Epoch 82/100
# 492/492 [==============================] - 0s 192us/step - loss: 0.0769 - acc: 0.9837 - val_loss: 0.0669 - val_acc: 0.9836
# Epoch 83/100
# 492/492 [==============================] - 0s 206us/step - loss: 0.0774 - acc: 0.9837 - val_loss: 0.0666 - val_acc: 0.9836
# Epoch 84/100
# 492/492 [==============================] - 0s 127us/step - loss: 0.0746 - acc: 0.9837 - val_loss: 0.0764 - val_acc: 0.9918
# Epoch 85/100
# 492/492 [==============================] - 0s 126us/step - loss: 0.0768 - acc: 0.9837 - val_loss: 0.0654 - val_acc: 0.9836
# Epoch 86/100
# 492/492 [==============================] - 0s 116us/step - loss: 0.0757 - acc: 0.9837 - val_loss: 0.0651 - val_acc: 0.9836
# Epoch 87/100
# 492/492 [==============================] - 0s 146us/step - loss: 0.0753 - acc: 0.9837 - val_loss: 0.0654 - val_acc: 0.9836
# Epoch 88/100
# 492/492 [==============================] - 0s 124us/step - loss: 0.0746 - acc: 0.9837 - val_loss: 0.0642 - val_acc: 0.9836
# Epoch 89/100
# 492/492 [==============================] - 0s 138us/step - loss: 0.0743 - acc: 0.9837 - val_loss: 0.0641 - val_acc: 0.9836
# Epoch 90/100
# 492/492 [==============================] - 0s 142us/step - loss: 0.0740 - acc: 0.9837 - val_loss: 0.0634 - val_acc: 0.9836
# Epoch 91/100
# 492/492 [==============================] - 0s 117us/step - loss: 0.0731 - acc: 0.9837 - val_loss: 0.0627 - val_acc: 0.9836
# Epoch 92/100
# 492/492 [==============================] - 0s 131us/step - loss: 0.0710 - acc: 0.9837 - val_loss: 0.0681 - val_acc: 0.9918
# Epoch 93/100
# 492/492 [==============================] - 0s 127us/step - loss: 0.0722 - acc: 0.9837 - val_loss: 0.0627 - val_acc: 0.9836
# Epoch 94/100
# 492/492 [==============================] - 0s 125us/step - loss: 0.0724 - acc: 0.9837 - val_loss: 0.0620 - val_acc: 0.9836
# Epoch 95/100
# 492/492 [==============================] - 0s 136us/step - loss: 0.0711 - acc: 0.9837 - val_loss: 0.0612 - val_acc: 0.9836
# Epoch 96/100
# 492/492 [==============================] - 0s 136us/step - loss: 0.0713 - acc: 0.9858 - val_loss: 0.0624 - val_acc: 0.9836
# Epoch 97/100
# 492/492 [==============================] - 0s 139us/step - loss: 0.0704 - acc: 0.9837 - val_loss: 0.0616 - val_acc: 0.9836
# Epoch 98/100
# 492/492 [==============================] - 0s 241us/step - loss: 0.0706 - acc: 0.9837 - val_loss: 0.0601 - val_acc: 0.9836
# Epoch 99/100
# 492/492 [==============================] - 0s 127us/step - loss: 0.0703 - acc: 0.9837 - val_loss: 0.0601 - val_acc: 0.9836
# Epoch 100/100
# 492/492 [==============================] - 0s 138us/step - loss: 0.0715 - acc: 0.9837 - val_loss: 0.0606 - val_acc: 0.9836

# %%
# Save model
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# Function for calculating the probability that the 
# given sample data is malignant.
def calcProb(sample):
    # load json and create model
    json_file = open('model.json', 'r')
    loaded_model_json = json_file.read()
    json_file.close()
    loaded_model = model_from_json(loaded_model_json)
    # load weights into new model
    loaded_model.load_weights("model.h5")
    print("Loaded model from disk")

    loaded_model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
    loaded_score = loaded_model.evaluate(X_test.values, Y_test.values)
    print("%s: %.2f%%" % (loaded_model.metrics_names[1], loaded_score[1]*100))

    for i in range(0,10):
        print("X_test.value = ")
        print(X_test.values[i].reshape(1,-1))
        print("Y_test.value = ")
        print(Y_test.values[i])
        print("Predicted = ")
        print(loaded_model.predict_proba(X_test.values[i].reshape(1,-1), batch_size=1))

# %%
# filename2 = "breast-cancer_csv.csv"

# # Initialize datafrmae
# dataframe2 = pd.read_csv(filename2, header=0)
# # dataframe = dataframe.drop(0, 1)
# # columns = []
# # dataframe.columns = columns

# print(dataframe2)
# Out:
#        age menopause tumor-size inv-nodes node-caps  deg-malig breast  \
# 0    40-49   premeno      15-19       0-2       yes          3  right
# 1    50-59      ge40      15-19       0-2        no          1  right
# 2    50-59      ge40      35-39       0-2        no          2   left
# 3    40-49   premeno      35-39       0-2       yes          3  right
# 4    40-49   premeno      30-34       3-5       yes          2   left
# 5    50-59   premeno      25-29       3-5        no          2  right
# 6    50-59      ge40      40-44       0-2        no          3   left
# 7    40-49   premeno      10-14       0-2        no          2   left
# 8    40-49   premeno        0-4       0-2        no          2  right
# 9    40-49      ge40      40-44     15-17       yes          2  right
# 10   50-59   premeno      25-29       0-2        no          2   left
# 11   60-69      ge40      15-19       0-2        no          2  right
# 12   50-59      ge40      30-34       0-2        no          1  right
# 13   50-59      ge40      25-29       0-2        no          2  right
# 14   40-49   premeno      25-29       0-2        no          2   left
# 15   30-39   premeno      20-24       0-2        no          3   left
# 16   50-59   premeno      10-14       3-5        no          1  right
# 17   60-69      ge40      15-19       0-2        no          2  right
# 18   50-59   premeno      40-44       0-2        no          2   left
# 19   50-59      ge40      20-24       0-2        no          3   left
# 20   50-59      lt40      20-24       0-2       NaN          1   left
# 21   60-69      ge40      40-44       3-5        no          2  right
# 22   50-59      ge40      15-19       0-2        no          2  right
# 23   40-49   premeno      10-14       0-2        no          1  right
# 24   30-39   premeno      15-19       6-8       yes          3   left
# 25   50-59      ge40      20-24       3-5       yes          2  right
# 26   50-59      ge40      10-14       0-2        no          2  right
# 27   40-49   premeno      10-14       0-2        no          1  right
# 28   60-69      ge40      30-34       3-5       yes          3   left
# 29   40-49   premeno      15-19     15-17       yes          3   left
# ..     ...       ...        ...       ...       ...        ...    ...
# 256  50-59      ge40      40-44       0-2        no          2   left
# 257  60-69      ge40      25-29       0-2        no          3   left
# 258  40-49   premeno      30-34       3-5       yes          2  right
# 259  50-59      ge40      20-24       0-2        no          2   left
# 260  70-79      ge40      20-24       0-2        no          3   left
# 261  30-39   premeno      25-29       0-2        no          1   left
# 262  60-69      ge40      30-34       0-2        no          2   left
# 263  40-49   premeno      20-24       3-5       yes          2  right
# 264  50-59      ge40      30-34      9-11       NaN          3   left
# 265  50-59      ge40        0-4       0-2        no          2   left
# 266  40-49   premeno      20-24       0-2        no          3  right
# 267  30-39   premeno      35-39       0-2        no          3   left
# 268  60-69      ge40      30-34       0-2        no          1   left
# 269  60-69      ge40      20-24       0-2        no          1   left
# 270  50-59      ge40      25-29       6-8        no          3   left
# 271  50-59   premeno      35-39     15-17       yes          3  right
# 272  30-39   premeno      20-24       3-5       yes          2  right
# 273  40-49   premeno      20-24       6-8        no          2  right
# 274  50-59      ge40      35-39       0-2        no          3   left
# 275  50-59   premeno      35-39       0-2        no          2  right
# 276  40-49   premeno      25-29       0-2        no          2   left
# 277  40-49   premeno      35-39       0-2        no          2  right
# 278  50-59   premeno      30-34       3-5       yes          2   left
# 279  40-49   premeno      20-24       0-2        no          2  right
# 280  60-69      ge40      15-19       0-2        no          3  right
# 281  50-59      ge40      30-34       6-8       yes          2   left
# 282  50-59   premeno      25-29       3-5       yes          2   left
# 283  30-39   premeno      30-34       6-8       yes          2  right
# 284  50-59   premeno      15-19       0-2        no          2  right
# 285  50-59      ge40      40-44       0-2        no          3   left
#
#     breast-quad irradiat                 Class
# 0       left_up       no     recurrence-events
# 1       central       no  no-recurrence-events
# 2      left_low       no     recurrence-events
# 3      left_low      yes  no-recurrence-events
# 4      right_up       no     recurrence-events
# 5       left_up      yes  no-recurrence-events
# 6       left_up       no  no-recurrence-events
# 7       left_up       no  no-recurrence-events
# 8     right_low       no  no-recurrence-events
# 9       left_up      yes  no-recurrence-events
# 10     left_low       no  no-recurrence-events
# 11      left_up       no  no-recurrence-events
# 12      central       no  no-recurrence-events
# 13      left_up       no  no-recurrence-events
# 14     left_low      yes     recurrence-events
# 15      central       no  no-recurrence-events
# 16      left_up       no  no-recurrence-events
# 17      left_up       no  no-recurrence-events
# 18      left_up       no  no-recurrence-events
# 19      left_up       no  no-recurrence-events
# 20     left_low       no     recurrence-events
# 21      left_up      yes  no-recurrence-events
# 22     left_low       no  no-recurrence-events
# 23      left_up       no  no-recurrence-events
# 24     left_low      yes     recurrence-events
# 25      left_up       no  no-recurrence-events
# 26     left_low       no  no-recurrence-events
# 27      left_up       no  no-recurrence-events
# 28     left_low       no  no-recurrence-events
# 29     left_low       no     recurrence-events
# ..          ...      ...                   ...
# 256    left_low       no  no-recurrence-events
# 257   right_low      yes     recurrence-events
# 258    left_low       no  no-recurrence-events
# 259     left_up       no     recurrence-events
# 260     left_up       no  no-recurrence-events
# 261     central       no  no-recurrence-events
# 262    left_low       no  no-recurrence-events
# 263    right_up      yes     recurrence-events
# 264    left_low      yes  no-recurrence-events
# 265     central       no  no-recurrence-events
# 266    left_low      yes  no-recurrence-events
# 267    left_low       no     recurrence-events
# 268     left_up       no  no-recurrence-events
# 269    left_low       no  no-recurrence-events
# 270    left_low      yes     recurrence-events
# 271    right_up       no     recurrence-events
# 272     left_up      yes  no-recurrence-events
# 273    left_low      yes  no-recurrence-events
# 274    left_low       no  no-recurrence-events
# 275     left_up       no  no-recurrence-events
# 276     left_up      yes  no-recurrence-events
# 277    right_up       no  no-recurrence-events
# 278    left_low      yes  no-recurrence-events
# 279    right_up       no  no-recurrence-events
# 280     left_up      yes  no-recurrence-events
# 281    left_low       no  no-recurrence-events
# 282    left_low      yes  no-recurrence-events
# 283    right_up       no  no-recurrence-events
# 284    left_low       no  no-recurrence-events
# 285    right_up       no  no-recurrence-events
#
# [286 rows x 10 columns]
